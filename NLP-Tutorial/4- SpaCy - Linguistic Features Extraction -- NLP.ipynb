# %% [markdown]
# # SpaCy Models
# https://spacy.io/usage/models

# %%
# !pip install -U spacy
# !pip install -U spacy-lookups-data
# !python -m spacy download en_core_web_sm

# %% [markdown]
# ###
# - Processing raw text intelligently is difficult: most words are rare, and it’s common for words that look completely different to mean almost the same thing.
# - The same words in a different order can mean something completely different.
# - While it’s possible to solve some problems starting from only the raw characters, it’s usually better to use linguistic knowledge to add useful information.
# ![alt text](https://spacy.io/pipeline-7a14d4edd18f3edfee8f34393bff2992.svg)

# %% [markdown]
# ## Tokenizer
# Tokenization is the task of splitting a text into meaningful segments, called tokens. The input to the tokenizer is a unicode text, and the output is a Doc object.*italicized text*

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm') # spacy trained model
nlp

# %%
doc = nlp('Apple is looking at buying U.K. startup for $1 Billion')

# %%
for token in doc:
  print(token.text)
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# Billion

# %%
doc = nlp("Apple isn't looking at buying U.K. startup for $1 Billion")
for token in doc:
  print(token.text)
# Out:
# Apple
# is
# n't
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# Billion

# %% [markdown]
# ## Tagger - Part of Speech Tagging -- POS

# %%
doc
# Out:
# Apple isn't looking at buying U.K. startup for $1 Billion

# %%
for token in doc:
  print(token.text, token.lemma_)
# Out:
# Apple Apple
# is be
# n't not
# looking look
# at at
# buying buy
# U.K. U.K.
# startup startup
# for for
# $ $
# 1 1
# Billion billion

# %%
for token in doc:
  print(f'{token.text:{15}} {token.lemma_:{15}} {token.pos_:{10}} {token.is_stop}')
# Out:
# Apple           Apple           PROPN      False
# is              be              AUX        True
# n't             not             PART       True
# looking         look            VERB       False
# at              at              ADP        True
# buying          buy             VERB       False
# U.K.            U.K.            PROPN      False
# startup         startup         NOUN       False
# for             for             ADP        True
# $               $               SYM        False
# 1               1               NUM        False
# Billion         billion         NUM        False

# %% [markdown]
# ## Parser - Dependency Parsing

# %%
# print(doc.noun_chunks)
for chunk in doc.noun_chunks:
  print(f'{chunk.text:{15}} {chunk.root.text:{15}} {chunk.root.dep_}')
# Out:
# Apple           Apple           nsubj
# U.K. startup    startup         dobj

# %% [markdown]
# ## Named Entity Recognition
# #### Example 1: "Apple is looking at buying U.K. startup for $1 billion"
# #### Example 2: "Ishu ate the Apple"

# %%
doc
# Out:
# Apple isn't looking at buying U.K. startup for $1 Billion

# %%
# print(doc.ents)
for ent in doc.ents:
  print(f'{ent.text:{15}} {ent.label_:{5}}')
# Out:
# Apple           ORG
# U.K.            GPE
# $1 Billion      MONEY

# %% [markdown]
# ## Sentence Segmentation

# %%
doc.sents

# %%
doc
# Out:
# Apple isn't looking at buying U.K. startup for $1 Billion

# %%
for sent in doc.sents:
  print(sent)
# Out:
# Apple isn't looking at buying U.K. startup for $1 Billion

# %%
doc1 = nlp("Welcome to 714 E. 10th Street. Thanks for watching. Please bring food and gifts.")

# %%
for sent in doc1.sents:
  print(sent)
# Out:
# Welcome to 714 E. 10th Street.
# Thanks for watching.
# Please bring food and gifts.

# %%
doc2 = nlp("Welcome to 714 E. 10th Street? Thanks for watching.")
for sent in doc2.sents:
  print(sent)
# Out:
# Welcome to 714 E. 10th Street?
# Thanks for watching.

# %%
doc3 = nlp("Welcome to 714 E. 10th Street_ Thanks for watching.")
for sent in doc3.sents:
  print(sent)
# Out:
# Welcome to 714 E. 10th Street_ Thanks for watching.

# %%
doc4 = nlp("Welcome to 714 E.... 10th Street .... Thanks for watching.")
for sent in doc4.sents:
  print(sent)
# Out:
# Welcome to 714 E....
# 10th Street ....
# Thanks for watching.

# %%
doc5 = nlp("Welcome to.*.KGP Talkie.*.Thanks for watching")
for sent in doc5.sents:
  print(sent)
# Out:
# Welcome to.*.KGP
# Talkie.*.Thanks for watching

# %%
# custom rule
def set_rule(doc):
  for token in doc[:-1]:
    if token.text == '...':
      doc[token.i + 1].is_sent_start = True
  return doc

# %%
nlp.remove_pipe('set_rule')
# Out:
# ('set_rule', <function __main__.set_rule>)

# %%
nlp.add_pipe(set_rule, before='parser')

# %%
doc6 = nlp("Welcome to KGP Talkie...Thanks... Like and Subsribe!")
for sent in doc6.sents:
  print(sent)
# Out:
# Welcome to KGP Talkie...
# Thanks...
# Like and Subsribe!

# %% [markdown]
# ## Visualization

# %%
from spacy import displacy

# %%
doc6
# Out:
# Welcome to KGP Talkie...Thanks... Like and Subsribe!

# %%
displacy.render(doc6, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8f0a14d7531f469d94845d4a66bb6506-0" class="displacy" width="770" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Welcome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">KGP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">Talkie...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Thanks...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">Subsribe!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f0a14d7531f469d94845d4a66bb6506-0-0" stroke-width="2px" d="M70,92.0 C70,47.0 135.0,47.0 135.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f0a14d7531f469d94845d4a66bb6506-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M135.0,94.0 L143.0,82.0 127.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f0a14d7531f469d94845d4a66bb6506-0-1" stroke-width="2px" d="M250,92.0 C250,47.0 315.0,47.0 315.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f0a14d7531f469d94845d4a66bb6506-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,94.0 L242,82.0 258,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f0a14d7531f469d94845d4a66bb6506-0-2" stroke-width="2px" d="M160,92.0 C160,2.0 320.0,2.0 320.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f0a14d7531f469d94845d4a66bb6506-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320.0,94.0 L328.0,82.0 312.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f0a14d7531f469d94845d4a66bb6506-0-3" stroke-width="2px" d="M520,92.0 C520,47.0 585.0,47.0 585.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f0a14d7531f469d94845d4a66bb6506-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M585.0,94.0 L593.0,82.0 577.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f0a14d7531f469d94845d4a66bb6506-0-4" stroke-width="2px" d="M520,92.0 C520,2.0 680.0,2.0 680.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f0a14d7531f469d94845d4a66bb6506-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M680.0,94.0 L688.0,82.0 672.0,82.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
displacy.render(doc6, style='dep', options={'compact':True, 'distance': 90}, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f9f1460154194fa3804938fec5b57c1d-0" class="displacy" width="770" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Welcome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">KGP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">Talkie...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Thanks...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">Subsribe!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f9f1460154194fa3804938fec5b57c1d-0-0" stroke-width="2px" d="M62,92.0 62,77.0 137.0,77.0 137.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f9f1460154194fa3804938fec5b57c1d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M137.0,94.0 L141.0,86.0 133.0,86.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f9f1460154194fa3804938fec5b57c1d-0-1" stroke-width="2px" d="M242,92.0 242,77.0 317.0,77.0 317.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f9f1460154194fa3804938fec5b57c1d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M242,94.0 L238,86.0 246,86.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f9f1460154194fa3804938fec5b57c1d-0-2" stroke-width="2px" d="M152,92.0 152,62.0 320.0,62.0 320.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f9f1460154194fa3804938fec5b57c1d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320.0,94.0 L324.0,86.0 316.0,86.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f9f1460154194fa3804938fec5b57c1d-0-3" stroke-width="2px" d="M512,92.0 512,77.0 587.0,77.0 587.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f9f1460154194fa3804938fec5b57c1d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M587.0,94.0 L591.0,86.0 583.0,86.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f9f1460154194fa3804938fec5b57c1d-0-4" stroke-width="2px" d="M512,92.0 512,62.0 680.0,62.0 680.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f9f1460154194fa3804938fec5b57c1d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M680.0,94.0 L684.0,86.0 676.0,86.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
doc
# Out:
# Apple isn't looking at buying U.K. startup for $1 Billion

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  isn't looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1 Billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>
