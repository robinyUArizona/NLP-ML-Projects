# %% [markdown]
# ## Working with Text Files

# %% [markdown]
# ### String Formatter

# %%
name = 'KGP Talkie'
print('The YouTube channel is {}'.format(name))

print(f'The Youtube channel is {name}')
# Out:
# The YouTube channel is KGP Talkie
# The Youtube channel is KGP Talkie

# %%
## minimum width and aligment between the col
# day value
# 1    10 
# 10     11

data_science_tuts = [('Python for Beginners', 19),
                     ('Feature Selection for Machine Learning', 11),
                     ('Machine Learning Tutorials', 19),
                     ('Deep Learning Tutorials', 19)]

print(data_science_tuts)
# Out:
# [('Python for Beginners', 19), ('Feature Selection for Machine Learning', 11), ('Machine Learning Tutorials', 19), ('Deep Learning Tutorials', 19)]

# %%
for info in data_science_tuts:
  print(f'{info[0]:{50}} {info[1]:{10}}')
# Out:
# Python for Beginners                                       19
# Feature Selection for Machine Learning                     11
# Machine Learning Tutorials                                 19
# Deep Learning Tutorials                                    19

# %%
# >, > ^
for info in data_science_tuts:
  print(f'{info[0]:>{50}} {info[1]:.>{10}}')
# Out:
#                               Python for Beginners ........19
#             Feature Selection for Machine Learning ........11
#                         Machine Learning Tutorials ........19
#                            Deep Learning Tutorials ........19

# %% [markdown]
# ### Working with .csv or .tsv files

# %%
# Load the data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6b60e9a9-f608-4300-b875-d8524d38c422" name="files[]" multiple disabled />
#      <output id="result-6b60e9a9-f608-4300-b875-d8524d38c422">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving moviereviews.tsv.txt to moviereviews.tsv.txt

# %%
import pandas as pd

# %%
data = pd.read_csv('moviereviews.tsv.txt', sep = '\t')
data.head()
# Out:
#   label                                             review
# 0   neg  how do films like mouse hunt get into theatres...
# 1   neg  some talented actresses are blessed with a dem...
# 2   pos  this has been an extraordinary year for austra...
# 3   pos  according to hollywood movies made in last few...
# 4   neg  my first press screening of 1998 and already i...

# %%
data.shape
# Out:
# (2000, 2)

# %%
data['label'].value_counts()
# Out:
# pos    1000
# neg    1000
# Name: label, dtype: int64
