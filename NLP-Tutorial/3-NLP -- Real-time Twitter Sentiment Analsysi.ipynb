# %% [markdown]
# ## US Election 2020 - Sentiment analysis of the tweets between Donald Trump vs. Warren

# %%
# !pip install tweepy
# import nltk
# nltk.download('punkt')

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import tweepy

# %%
# Get the data
log = pd.read_csv('Login.csv')

# %%
# Twitter API credentials
consumerKey = log['key'][0]
consumerSecret = log['key'][1]
accessToken = log['key'][2]
accessTokenSecret = log['key'][3]

# %%
# Create the authentication object
authenticate = tweepy.OAuthHandler(consumerKey, consumerSecret)

# Set the access token and access token secret
authenticate.set_access_token(accessToken, accessTokenSecret)

# Create the API object while passing in the auth information
api = tweepy.API(authenticate, wait_on_rate_limit = True)

# %% [markdown]
# ### Checking other twitter tweets

# %%
# # Extract 100 tweets from the twitter user
# posts = api.user_timeline(screen_name = "BillGates", count = 100, lang = "en", tweet_mode = "extended")

# # Print the last 5 tweets from the account
# print("Show the 5 recents tweets: \n")
# i = 1
# for tweet in posts[0:5]:
#   print(str(i) + ') ' + tweet.full_text + "\n")
#   i = i + 1

# %% [markdown]
# ### Get tweets stream and perform sentiment analysis

# %%
from tweepy import Stream 
from tweepy import StreamListener
import json
from textblob import TextBlob
from wordcloud import WordCloud

import re
import csv

# %%
trump = 0;
warren = 0;

header_name = ['Trump', 'Warren']

with open('sentiment.csv', 'w') as file:
    writer = csv.DictWriter(file, fieldnames = header_name)
    writer.writeheader()


## listener class, it will take a StreamListener
class Listener(StreamListener):


    ## Receives data from StreamListener
    def on_data(self, data):
        raw_twitts = json.loads(data)
        try:

            tweets = raw_twitts['text']
            tweets = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\s+)", " ", tweets).split())
            tweets = ' '.join(re.sub('RT', ' ', tweets).split())


            blob = TextBlob(tweets.strip())

            global trump
            global warren

            trump_sentiment = 0
            warren_sentiment = 0
            for sent in blob.sentences:
                if "Trump" in sent and "Warren" not in sent:
                    trump_sentiment = trump_sentiment + sent.sentiment.polarity
                else:
                    warren_sentiment = warren_sentiment + sent.sentiment.polarity
            
            trump = trump + trump_sentiment
            warren = warren + warren_sentiment

            with open('sentiment.csv', 'a') as file:
                writer = csv.DictWriter(file, fieldnames = header_name)
                info = {
                    'Trump': trump,
                    'Warren': warren
                }
                writer.writerow(info)

            print(tweets)
            print()
            print()
        except:
            print('Error got')


    
    def on_error(self, status):
        print(status)

# %%
# Create the authentication object
authenticate = tweepy.OAuthHandler(consumerKey, consumerSecret)

# Set the access token and access token secret
authenticate.set_access_token(accessToken, accessTokenSecret)

# %%
twitter_stream = Stream(authenticate, Listener())
twitter_stream.filter(track = ['Trump', 'Warren'])
# Out:
# Very cool Please thank him
#
#
# Trump s new order banning permanent residents from entry is not a genuine response to the pandemic it s an effort to rewrite t
#
#
# Trump s purge of Inspectors General continues as he removes the one who reported critical shortages of protective gear
#
#
# When I say Donald Trump is the most corrupt president in modern American history this is what I m talking about Monty Benn
#
#
# 67 000 Americans have died and Trump is rage tweeting again He s a monster
#
#
# sdv sex fuck kpop jennie thread compilation link bfts nsfw 18 jikook au porn jisoo jimin gg stan bg follow trick https t co siXJJk0q7q
#
#
# Empresa de Warren Buffett vende todas sus participaciones en aerol neas de EEUU https t co 5m2YMfy9Xb https t co zihx
#
#
# I can t imagine how many ppl out there are up all night worrying about their bills right now Worrying how they are goi
#
#
# LET THEM EAT DI Federal Judge rejects White House attempts to lower nutritional standards in America s public school
#
#
# EntheosShines realDonaldTrump CROWDSTRIKE FINALLY ADMITS Mozambique DID NOT HACK DNC amp amp GIVE EMAILS TO WIKIL https t co fMz8Se3ijj
#
#
# So true although Honest Abe wasn t bad Thank you
#
#
# This is an example if what I am dealing with in addition to the threats and harrassment online I am not unbalanced
#
#
# Trump closed the door behind me threw me up against the wall and banged my head There was a real struggle and I
#
#
# 4 15 Donald J Trump Goes to War VS W H O amp The Media Trudeau Going Down for Financial Crimes https t co ChUD
#
#
# VIDEO Trump campaign releases brutal ad exposing Dem Party s double standard on believing women https t co X7N6GZENvc
#
#
# Anyone else notice how Trump used the Defense Production Act to keep meat factories open but not to make more Personal Prot
#
#
# By February 14 Dr Fauci was telling reporters that Covid 19 had the makings of a global pandemic and Trump did not
#
#
# Sorry still hate this guy He s better than trump I guess
#
#
# Hey Like that Can you blue ones w vote on them Trump is going to have his followers red mask
#
#
# I urge and the House of Representatives to find some testicular fortitude reject Trump s obstructions and b
#
#
# Thank you
#
#
# Donald Trump kalo olahraga ga pemanasan jadi Donald Kram yaksip
#
#
# oxy deal doesn t work at 20 a barrel Warren Buffett OOTT
#
#
# Anita Hill tells the NYT that she s calling for an independent investigation into allegations against Joe Biden and Donald Trum
#
#
# In November I will vote for Joe Biden to make sure we get rid of Trump How will you vote
#
#
# How do you hit Trump on his rape allegations when Biden is accused of rape How do you hit him for cutting social progr
#
#
# amp Jordan had it right from the start Pro Hillary agents in Comey s FBI abused their power to try to ta
#
#
# Africa got te cure for covid shout out too Madagascar love Africa and shout out to trump for investing 2 5 millio https t co Adc8s9fV7u
#
#
# President Trump believes that if fewer people turn out to vote he ll win re election That s why he s against universal
#
#
# Former Apprentice contestant Summer Zervos sexual misconduct lawsuit against Donald Trump is headed to New York https t co Oh57UHcDEK
#
#
# https t co 1mf1Qlj7pi
#
#
# You don t have to forgive or forget the bad shit that happened in the George W Bush admin in order to appreciate that the
#
#
# Donald Trump s day so far Takes North Korea s word for it that Kim Jong Un is alive Seems thrilled about it Remem
#
#
# I got issues with Trump and Clinton because imo they are not good people I got no issues with anyone else on a per https t co J02pmqeUSp
#
#
# President Trump dropped the hammer on Ilhan Omar and backed calls for an investigation into her spendthrift ways https t
#
#
# We left a playbook He ignored it We created an office to prepare for pandemics He gutted it We had CDC officials in Chi
#
#
# Er US allies Taiwan South Korea Japan Vietnam all saw the same coronavirus data statistics at the same
#
#
# Looking at her bio I don t believe this is going quite how she would have wanted https t co ieXvWiAOd4
#
#
# Good Job there
#
#
# As if Donald Trump will acknowledge the nonsense he wrote or tweeted
#
#
# Shipp On another note How can we get Trump to STOP the deadly 5G towers going up while this quarantine is going on
#
#
# I urge and the House of Representatives to find some testicular fortitude reject Trump s obstructions and b
#
#
# There s a lot of toxic masculinity talk coming from Trump s twitter feed today he s not fearless or brave he s a coward
#
#
# Lev Parnas released a tape of Trump basically ordering a hit on a U S Ambassador who was getting in the way of his att
#
#
# The FBI Didn t Frame Michael Flynn That s Just Trump s Excuse for a Prospective Pardon https t co Fo3qypPgXe
#
#
#
#
# They ve been conditioning us for a long time now Theres a war for our minds Trump won and m https t co 85Gt1U41lc
#
#
# https t co lzogcW9D7d
#
#
# https t co pBIEcs5f2e Love him or hate him is a smart guy and a great student of history The 3 reasons he outl
#
#
# Trump and his racist administration have not helped the Native American communities and t
#
#
# Nicolle Wallace has your number Donald When Trump betrays America America hits b
#
#
# Ultron browsed the internet for 30 seconds and came to the conclusion that the only way to save humanity is to destroy earth
#
#
# When I say Donald Trump is the most corrupt president in modern American history this is what I m talking about Monty Benn
#
#
# So he is spending an extra 55 cents for every person that got a check If there were 30 million letters sent out he jus
#
#
# 2020 Right Trump s family and Trump s Golf and Trump s Christmas decorations yes even this and Trump s rallies
#
#
# I am a HUGE fan of Always love watching her and appearing on her show https t co 6Cx4kEwccY
#
#
# Fun Fact if you tell people on social media you re not voting for a rapist both Trump and Biden supporters lose their minds
#
#
# I like that all these BB commenters are skeptical Trump on the other hand just tweets how happy he https t co lZByyvwn7P
#
#
# The FBI Didn t Frame Michael Flynn That s Just Trump s Excuse for a Prospective Pardon https t co Fo3qypPgXe
#
#
# North Korea killed Otto Warmbier and Trump praised the guy who gave the order That sucks like an Electrolux
#
#
# Trump keeps punishing those who tell Americans the truth https t co QjDGteJa2y
#
#
# President Bush presided over the greatest security failure in US history and responded to it by starting two pointless
#
#
# Very cool Please thank him https t co 7nc79fCFip
#
#
# That s why Mexico wants that wall up and prepared to pay for it now keep them thar https t co IOG6ULsolN
#
#
# PR Trump moves on Friday night to replace watchdog who revealed his coronavirus failures report https t co fQPHCjDTRg
#
#
# Donald Trump removes US from global initiative to develop coronavirus treatments and vaccines https t co SlxKsIU9OU
#
#
# 140 000 Minnesotans won t receive relief just because 1 family member is an immigrant w o a Social Security number There is
#
#
# Love it
#
#
# Just so you know how survivors are treated TaraReade has had her real social security number fake websites amp fake social me
#
#
# Very cool Please thank him
#
#
# Watch Trump find a way to blame the Obama administration ORDER YOUR BEE SUITS NOW
#
#
# No surprise there trump is only interested in things that will make money for him
#
#
# China welcomes a polarized paralyzed America writing in the that on technology trade
#
#
# In a nutshell this is why I m running to ReplacePelosi Our Republic is in crisis While the GOP openly promotes fa
#
#
# Hoping covid continues to spread among trump supporters is not a solid political ideology or organizing strategy
#
#
# Trump hasn t asked for forgiveness The weight of 62k dead Americans weigh on his s https t co lxHsuMgqeA
#
#
# and more importantly she s SMA trump is scared of her as he is of most women
#
#
# The allegations are bullshit Anyone still pushing this is a dishonest hack Trump has over 2 dozen legi
#
#
# I ve said this 1000x already I hate the antivax crowd Hate em However I will NOT let my famil https t co ULgzJpgUtU
#
#
# Join me for a quick laugh about the funniest Trump kill shot on Biden Ever https t co xn6U5w5iZe
#
#
# New Record US Federal Debt 24 974 trillion 1 287 trillionen in April 5 027 trillionen since Trump took office
#
#
# Every 44 seconds in April Congratulations to the self called Grim Reaper Sen Mitch McCon
#
#
# INMATE Isn t https t co fRY8ooMQFe
#
#
# Dear Firing the person who told you that some hospitals are not getting medical supplies and PPE does not ch
#
#
# nalexander Hell even the Trump https t co hsrg0JtWHD
#
#
# SCOOP A federal judge in Florida has granted an order against Mark Grenon and the Genesis II church to immediately stop al
#
#
# So true although Honest Abe wasn t bad Thank you
#
#
# We left a playbook He ignored it We created an office to prepare for pandemics He gutted it We had CDC officials in Chi
#
#
# PM Modi blocked again by Donald Trump s wife Melina and daughter Ivanka on Twitter
#
#
# Very cool Please thank him
#
#
# At this rate if you don t support Trump and you re a Republican you ve gone entirely mad
#
#
# Californians made my day yesterday THEY CAN FLIP THIS STATE RED First Trump Rally should be On the Beach in Huntington Cali
#
#
# Rolls amp Royce for you and me
#
#
# The Trump cultists are raising an entire generation of morons who think entrapment is when you lie to a cop who identi
#
#
# In November I will vote for Joe Biden to make sure we get rid of Trump How will you vote
#
#
# My brilliant spouse recommends we shred then send back to Trump the letters that accompany the stimulus checks therefo
#
#
# I urge and the House of Representatives to find some testicular fortitude reject Trump s obstructions and b
#
#
# Listen Now djradtipptoppp Odd Tapes Of President Trump Genociding The Country hits https t co wJdXYzQGpc https t co P5gjPJy1lR
#
#
# You don t have to forgive or forget the bad shit that happened in the George W Bush admin in order to appreciate that the
#
#
# ReaalAmerican How many people are you willing to see die to get Trump out of office A round number will do
#
#
# Psychotic
#
#
# And for goodness sake DontTestDontTell
#
#
# sdv sex fuck kpop jennie thread compilation link bfts nsfw 18 jikook au porn jisoo jimin gg stan bg follow trick https t co 71opHLixy1
#
#
#
#
#
# Welp only a little over 2 hours left until Trump s retaliatory firing of the Intelligence Community Inspector General becom
#
#
# JC You keep throwing T https t co 4BTgMpBJgc
#
#
# Outrageous don t defend Trump memo uncovered written by top Republican strategist Beltway insiders and strategists h
#
#
# Marc Short chief of staff to Pence repeatedly questioned the data being shared with Trump and said he did not believe t
#
#
# Nicole Wallace is absolutely right Biden was getting smeared And she s the first one at that I ve heard say it Let T
#
#
# There s a lot of toxic masculinity talk coming from Trump s twitter feed today he s not fearless or brave he s a coward
#
#
# WOW The state of New York sent a random twitter guy 69 1 million for 1 450 ventilators at least triple the standard pri
#
#
# If we get Sanders back in as a result Trump gets 4 more years and maybe two more picks on the SCOT https t co rGKpahhojZ
#
#
# Very cool Please thank him
#
#
# Let s help get to 1 million followers https t co eBOcQYh6bF
#
#
# nut More than one politician can be a rapist you idiot Just because trump is https t co JOPfRWeUKg
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     590                 if len(mvb) <= chunk_left:
# --> 591                     n = self._safe_readinto(mvb)
#     592                     self.chunk_left = chunk_left - n
#
# ~\Anaconda3\lib\http\client.py in _safe_readinto(self, b)
#     637             if not n:
# --> 638                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#     639             mvb = mvb[n:]
#
# IncompleteRead: IncompleteRead(0 bytes read, 512 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     424             try:
# --> 425                 yield
#     426
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     601         except IncompleteRead:
# --> 602             raise IncompleteRead(bytes(b[0:total_bytes]))
#     603
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-10-162b3277d007> in <module>
#       1 twitter_stream = Stream(authenticate, Listener())
# ----> 2 twitter_stream.filter(track = ['Trump', 'Warren'])
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# ~\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     527                         # raised during streaming, so all calls with incorrect
#     528                         # Content-Length are caught.
# --> 529                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     530
#     531         if data:
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     441             except (HTTPException, SocketError) as e:
#     442                 # This includes IncompleteRead.
# --> 443                 raise ProtocolError("Connection broken: %r" % e, e)
#     444
#     445             # If no exception is thrown, we should avoid cleaning up
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read)', IncompleteRead(0 bytes read))
