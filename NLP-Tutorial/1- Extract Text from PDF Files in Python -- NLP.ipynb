# %% [markdown]
# ## Working with .PDF Files

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz (77kB)
#      |████████████████████████████████| 81kB 2.2MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61086 sha256=89d846b745682f1615ee7650611c6ef1c88023e72ea3a33e3ed2db332ebe6a1f
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
import PyPDF2 as pdf

# %%
# Load the data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f3b38e6f-06b7-4676-a123-0fba29cb886e" name="files[]" multiple disabled />
#      <output id="result-f3b38e6f-06b7-4676-a123-0fba29cb886e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Robin-Resume-V.0.4.pdf to Robin-Resume-V.0.4.pdf

# %%
file = open('Robin-Resume-V.0.4.pdf', 'rb')
file
# Out:
# <_io.BufferedReader name='Robin-Resume-V.0.4.pdf'>

# %%
pdf_reader = pdf.PdfFileReader(file)
pdf_reader

# %%
# help(pdf_reader)

# %%
## Is it encrypted?
pdf_reader.getIsEncrypted()
# Out:
# False

# %%
## How many pages?
pdf_reader.getNumPages()
# Out:
# 1

# %%
## Get information from particular page
page1 = pdf_reader.getPage(0)
page1.extractText()
# Out:
# 'ROBIN\nS YADAV DATA SCIENTIST\n & MACHINE LEARNING ENGINEER\n   CONTACT\n ˜ yrobins95@gmail.com\n ˚ (208) 226 \n- 4837\n ˛ Tucson\n, AZ ˜ linkedin.com/in/\nrobinyuarizona/\n ˚ github.com/\nrobinyUArizona\n  EDUCATION\n May \n20\n20\n UNIVERSITY OF \nARIZONA \nŒ Tucson, AZ\n Master of Science \nin Electrical and \nComputer Eng\nineering [4.0/4.0]\n  May \n201\n8 BOISE STATE UNIVERSITY \nŒ Boise, ID\n Bachelor of Science \nin \nElectrical \nEngineering\n [3.7/4.0]\n  RELEVA\nNT COURSEWORK\n  Machine learning and Data Analy\ntics  Statistical Machine Learning\n  Optimization for Machine Learning\n  Data Mining of Business Intelligence\n  Big Data Analy\ntics\n  MANAGEMENT SKILLS\n  Project and \nTeam\n Management\n  Trello, \nGit, Excel,\n Powerpoint\n  TECHNICAL SKILLS\n  Programming Languages:\n Python \n(Scikit\n-learn\n, TensorFlow, Keras\n, Django\n, nltk, \nspacy, \ngenism, \nTextBlob\n), R, SQL, Pyspark\n  Data Analysis:\n Numpy, Pandas, \ndpylr\n  Data Visualization:\n Matplotlib, \nSeaborn, ggplot2\n, Tableau\n  Big Data\n: Hadoop, Hive, H\nDFS\n, AWS, G\noogle Cloud Platform\n  Linear Regression, Logistic \nRegression, Naïve Bayes, Decision \nTree, K\n-Nearest Neighbors, Support \nVector Machines, Neural Networ\nk, \nK-means, PCA\n  Others: \nUnix, Linux\n    DATA SCIENCE PROJECTS\n Hotel Booking Demand\n - Python \n- Kaggle\n   Developed\n a predictive model\n-classification\n which\n predicts\n booking\n cancellations\n for\n the\n hotels\n (which\n cost\n around\n 40% for\n the\n hospitality\n industries)\n by using\n best\n chosen\n ML algorithm\n (MLP\n-NN) with\n an accuracy\n (conducting error\n analysis) \nof 81.7\n%.  Performed \nfeature engineering\n to \nunderstand cause and effect \nrelationship between \nfeatures from the dataset\n, and \noversampling\n techniques to handle imbalance\nd issue.\n Also, \ncross\n-validation\n method is \nused for evaluating 5 \nclassification algorithms\n.  Job Salary Prediction\n Œ Python \n  Developed a \npredictive model\n-regression\n to predict the employee \nsalaries based on \ntheir information such as title, degree, experience \netc. \n by using best selected algorithm \n(Gradient Boosting)\n with MSE\n (conducting error\n or deviation\n analysis)\n of 357.04\n compare to \nbaseline mode of MSE of \n963.92\n.  Dimensionality Reduction \nŒ PCA\n and\n Grid Search\n (to\n tune\n the\n model\n parameters\n) were\n used\n to achieve\n better\n model\n performance\ns.  Mini Projects: Natural Language Processing, Deep Learning\n  Bill Gates \nTwitter Sentimental Analysis\n Œ this \nprogram parses the \ntweets fetched from Twitter using \nPython\n and\n output the insight of \nwhether the Bill Gates \ntweets are negative or positive.\n  What makes\n comedian Ali Wong is different than other comedians \n(topic)\n? The goal is to know words spoken by the comedians (topic) \nusing \nLatent Dirichlet Allocation (LDA)\n  Built a \nmovie recommendation engine\n with\n the Python\n and \nMachine \nLearning\n using cosine similarity matrix\n (similarity between \nmovies\n) to \nrecommend user choice of movies prior to user past movies.\n  EXPERIENCE\n Graduate Teaching Assistant \n Aug 2018\n Œ May 2020\n                        \nTucson, AZ\n  Lecture\nd lab topics and \ntaught\n 300 plus undergraduate students on \nhow to debug and test the electrical and electronic circuits using test \nequipment. Also, organized lab parts, graded prelab and lab reports.\n    Graduate \nResearch\n Assistant \n May 2019 \nŒ Jan \n2020                        \nTucson, AZ\n  Due to unprecedent growth of the data collection, building\n and \ntraining\n Machine Learning system is not feasible\n. Hence, the need of \ndata distribution between \nsystems, \nand\n the sending and \nthe \nreceiving compressed information (\ndata) between\n these\n system\ns will\n help \nto speed up the learning process faster by sacrificing \nonly \nlimited \ninformation\n.   Research\n different \nquantization optimizati ...
