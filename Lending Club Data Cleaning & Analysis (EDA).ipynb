# %%
dbutils.fs.ls("/FileStore/tables")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[132]: [FileInfo(path=&#39;dbfs:/FileStore/tables/LoanStats_2018Q4-1.csv&#39;, name=&#39;LoanStats_2018Q4-1.csv&#39;, size=65699395),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/LoanStats_2018Q4-2.csv&#39;, name=&#39;LoanStats_2018Q4-2.csv&#39;, size=65699395),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/LoanStats_2018Q4-3.csv&#39;, name=&#39;LoanStats_2018Q4-3.csv&#39;, size=65623845),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/LoanStats_2018Q4.csv&#39;, name=&#39;LoanStats_2018Q4.csv&#39;, size=65699395),
#  FileInfo(path=&#39;dbfs:/FileStore/tables/hotel_bookings.csv&#39;, name=&#39;hotel_bookings.csv&#39;, size=16855599),
# ...

# %%
## File Location and type
file_location = "dbfs:/FileStore/tables/LoanStats_2018Q4.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for csv files. For other file types, these will be ignored.
df = spark.read.format(file_type)\
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location) 

# display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[134]: 128416</div>

# %%
## Data types for each column
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: string (nullable = true)
# -- member_id: string (nullable = true)
# -- loan_amnt: integer (nullable = true)
# -- funded_amnt: integer (nullable = true)
# -- funded_amnt_inv: double (nullable = true)
# -- term: string (nullable = true)
# -- int_rate: string (nullable = true)
# -- installment: double (nullable = true)
# -- grade: string (nullable = true)
# -- sub_grade: string (nullable = true)
# -- emp_title: string (nullable = true)
# -- emp_length: string (nullable = true)
# -- home_ownership: string (nullable = true)
# -- annual_inc: double (nullable = true)
# -- verification_status: string (nullable = true)
# ...

# %%
# Create temporary table for regualar "SQL-query"
temp_table_name = "loanstats"
df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from loanstats limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select count(*) from loanstats
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>128416</td></tr></tbody></table></div>

# %%
## Summary statistics
df.describe().show() # show is 'Action' function
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
df_sel = df.select("term", "home_ownership", "grade", "purpose", "int_rate", "addr_state", "loan_status", "application_type", 
                   "loan_amnt", "emp_length", "annual_inc", "dti", "delinq_2yrs", "revol_util", "total_acc", "num_tl_90g_dpd_24m",
                  "dti_joint")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sel.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+--------------+------+--------+--------+----------+------------------+----------------+------------------+----------+------------------+-----------------+-------------------+----------+------------------+--------------------+------------------+
# summary|      term|home_ownership| grade| purpose|int_rate|addr_state|       loan_status|application_type|         loan_amnt|emp_length|        annual_inc|              dti|        delinq_2yrs|revol_util|         total_acc|  num_tl_90g_dpd_24m|         dti_joint|
# ...

# %%
df_sel.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[140]: DataFrame[term: string, home_ownership: string, grade: string, purpose: string, int_rate: string, addr_state: string, loan_status: string, application_type: string, loan_amnt: int, emp_length: string, annual_inc: double, dti: double, delinq_2yrs: int, revol_util: string, total_acc: int, num_tl_90g_dpd_24m: int, dti_joint: double]</div>

# %%
df_sel.describe("term", "loan_amnt", "emp_length", "annual_inc", "dti", "delinq_2yrs", "revol_util", "total_acc").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+------------------+----------+------------------+-----------------+-------------------+----------+------------------+
# summary|      term|         loan_amnt|emp_length|        annual_inc|              dti|        delinq_2yrs|revol_util|         total_acc|
# +-------+----------+------------------+----------+------------------+-----------------+-------------------+----------+------------------+
#   count|    128412|            128412|    128412|            128412|           128175|             128412|    128256|            128412|
# ...

# %%
df_sel.describe("loan_amnt", "emp_length", "dti", "delinq_2yrs", "revol_util", "total_acc").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+----------+-----------------+-------------------+----------+------------------+
# summary|         loan_amnt|emp_length|              dti|        delinq_2yrs|revol_util|         total_acc|
# +-------+------------------+----------+-----------------+-------------------+----------+------------------+
#   count|            128412|    128412|           128175|             128412|    128256|            128412|
#    mean| 15971.32102139987|      null| 19.9331775307197|0.22783696227766875|      null|22.677413325857398|
# ...

# %%
# %sql
select distinct emp_length from loanstats limit 50
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_length</th></tr></thead><tbody><tr><td>5 years</td></tr><tr><td>9 years</td></tr><tr><td>null</td></tr><tr><td>1 year</td></tr><tr><td>n/a</td></tr><tr><td>2 years</td></tr><tr><td>7 years</td></tr><tr><td>8 years</td></tr><tr><td>4 years</td></tr><tr><td>6 years</td></tr><tr><td>3 years</td></tr><tr><td>10+ years</td></tr><tr><td>< 1 year</td></tr></tbody></table></div>

# %%
## Removing years, year, +, < from "emp_length" column
from pyspark.sql.functions import regexp_replace, regexp_extract
from pyspark.sql.functions import col

regex_string = 'years|year|\\+|\\<'
df_sel.select(regexp_replace(col("emp_length"), regex_string, "").alias("emplength_cleaned"), col("emp_length")).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+----------+
# emplength_cleaned|emp_length|
# +-----------------+----------+
#                1 |  &lt; 1 year|
#               10 | 10+ years|
#                1 |  &lt; 1 year|
#               n/a|       n/a|
#                5 |   5 years|
#                9 |   9 years|
#                3 |   3 years|
#               10 | 10+ years|
#               n/a|       n/a|
#               10 | 10+ years|
# +-----------------+----------+
# only showing top 10 rows
#
# </div>

# %%
## Other way of removing years, year, +, < from "emp_length" column
regex_string = '\\d+' ## only have decimal value -- remove everything else
df_sel.select(regexp_extract(col("emp_length"), regex_string, 0).alias("emplength_cleaned"), col("emp_length")).show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+----------+
# emplength_cleaned|emp_length|
# +-----------------+----------+
#                 1|  &lt; 1 year|
#                10| 10+ years|
#                 1|  &lt; 1 year|
#                  |       n/a|
#                 5|   5 years|
#                 9|   9 years|
#                 3|   3 years|
#                10| 10+ years|
#                  |       n/a|
#                10| 10+ years|
# +-----------------+----------+
# only showing top 10 rows
#
# </div>

# %%
df_sel.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------------+-----+------------------+--------+----------+-----------+----------------+---------+----------+----------+-----+-----------+----------+---------+------------------+---------+
#       term|home_ownership|grade|           purpose|int_rate|addr_state|loan_status|application_type|loan_amnt|emp_length|annual_inc|  dti|delinq_2yrs|revol_util|total_acc|num_tl_90g_dpd_24m|dti_joint|
# +----------+--------------+-----+------------------+--------+----------+-----------+----------------+---------+----------+----------+-----+-----------+----------+---------+------------------+---------+
# ...

# %%
df_sel = df_sel.withColumn("term_cleaned", regexp_replace(col("term"), "months", "")).\
          withColumn("emplen_cleaned", regexp_extract(col("emp_length"), "\\d+", 0))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sel.select("term", "term_cleaned", "emp_length", "emplen_cleaned").show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------+----------+--------------+
#       term|term_cleaned|emp_length|emplen_cleaned|
# +----------+------------+----------+--------------+
#  36 months|         36 |  &lt; 1 year|             1|
#  36 months|         36 | 10+ years|            10|
#  60 months|         60 |  &lt; 1 year|             1|
#  60 months|         60 |       n/a|              |
#  60 months|         60 |   5 years|             5|
#  36 months|         36 |   9 years|             9|
#  36 months|         36 |   3 years|             3|
#  36 months|         36 | 10+ years|            10|
#  36 months|         36 |       n/a|              |
# ...

# %%
df_sel.printSchema() ## schema will still show old datatypes --
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- term: string (nullable = true)
# -- home_ownership: string (nullable = true)
# -- grade: string (nullable = true)
# -- purpose: string (nullable = true)
# -- int_rate: string (nullable = true)
# -- addr_state: string (nullable = true)
# -- loan_status: string (nullable = true)
# -- application_type: string (nullable = true)
# -- loan_amnt: integer (nullable = true)
# -- emp_length: string (nullable = true)
# -- annual_inc: double (nullable = true)
# -- dti: double (nullable = true)
# -- delinq_2yrs: integer (nullable = true)
# -- revol_util: string (nullable = true)
# -- total_acc: integer (nullable = true)
# ...

# %%
## create another table "loanstatus_sel"
table_name = "loanstatus_sel"
df_sel.createOrReplaceTempView(table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from loanstatus_sel limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
## Covariance
df_sel.stat.cov("annual_inc", "loan_amnt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[150]: 221023240.20671284</div>

# %%
## Correlation
df_sel.stat.corr("annual_inc", "loan_amnt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[151]: 0.20106014148486612</div>

# %%
# %sql
select corr(loan_amnt, term_cleaned) from loanstatus_sel
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>corr(CAST(loan_amnt AS DOUBLE), CAST(term_cleaned AS DOUBLE))</th></tr></thead><tbody><tr><td>0.3925941141844238</td></tr></tbody></table></div>

# %%
df_sel.stat.crosstab("loan_status", "grade").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+-----+-----+-----+-----+----+---+---+----+
#  loan_status_grade|    A|    B|    C|    D|   E|  F|  G|null|
# +------------------+-----+-----+-----+-----+----+---+---+----+
#    In Grace Period|   74|  112|  146|  122|  54|  4|  1|   0|
#         Fully Paid| 1188| 1333| 1175|  807| 360| 36|  9|   0|
#               null|    0|    0|    0|    0|   0|  0|  0|   4|
# Late (31-120 days)|   68|  164|  234|  220| 142| 14|  7|   0|
#  Late (16-30 days)|   26|   78|  102|   81|  46|  9|  2|   0|
#            Current|36639|34139|29323|15823|5352|321| 79|   0|
#        Charged Off|   16|   35|   38|   19|   8|  3|  3|   0|
# ...

# %%
##
freq = df_sel.stat.freqItems(["purpose", "grade"], 0.3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
freq.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[154]: [Row(purpose_freqItems=[&#39;debt_consolidation&#39;, &#39;credit_card&#39;], grade_freqItems=[&#39;A&#39;, &#39;C&#39;, &#39;B&#39;])]</div>

# %%
#
df_sel.groupby("purpose").count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+-----+
#            purpose|count|
# +------------------+-----+
#               null|    4|
#              other| 7094|
#     small_business| 1051|
# debt_consolidation|70603|
#        credit_card|34961|
#             moving|  656|
#           vacation|  802|
#   renewable_energy|   71|
#              house|  823|
#                car| 1037|
#     major_purchase| 2303|
#            medical| 1499|
#   home_improvement| 7512|
# +------------------+-----+
#
# </div>

# %%
# 
df_sel.groupby("purpose").count().orderBy(col("count").desc()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+-----+
#            purpose|count|
# +------------------+-----+
# debt_consolidation|70603|
#        credit_card|34961|
#   home_improvement| 7512|
#              other| 7094|
#     major_purchase| 2303|
#            medical| 1499|
#     small_business| 1051|
#                car| 1037|
#              house|  823|
#           vacation|  802|
#             moving|  656|
#   renewable_energy|   71|
#               null|    4|
# +------------------+-----+
#
# </div>

# %%
from pyspark.sql.functions import count, mean, stddev_pop, min, max, avg
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
quantileProbs = [0.25, 0.5, 0.75, 0.9]
relError = 0.05
df_sel.stat.approxQuantile("loan_amnt", quantileProbs, relError)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[158]: [8400.0, 13000.0, 23000.0, 32000.0]</div>

# %%
quantileProbs = [0.25, 0.5, 0.75, 0.9]
relError = 0.0
df_sel.stat.approxQuantile("loan_amnt", quantileProbs, relError)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[159]: [8000.0, 14000.0, 21600.0, 32000.0]</div>

# %%
quantileProbs = [0.25, 0.5, 0.75, 0.9]
relError = 0.5
df_sel.stat.approxQuantile("loan_amnt", quantileProbs, relError)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[160]: [1000.0, 1000.0, 40000.0, 40000.0]</div>

# %%
##
from pyspark.sql.functions import isnan, when , count, col
df_sel.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df_sel.columns]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------+-----+-------+--------+----------+-----------+----------------+---------+----------+----------+---+-----------+----------+---------+------------------+---------+------------+--------------+
# term|home_ownership|grade|purpose|int_rate|addr_state|loan_status|application_type|loan_amnt|emp_length|annual_inc|dti|delinq_2yrs|revol_util|total_acc|num_tl_90g_dpd_24m|dti_joint|term_cleaned|emplen_cleaned|
# +----+--------------+-----+-------+--------+----------+-----------+----------------+---------+----------+----------+---+-----------+----------+---------+------------------+---------+------------+--------------+
# ...

# %%
# %sql
select loan_status, count(*) from loanstats group by loan_status order by 2 desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>loan_status</th><th>count(1)</th></tr></thead><tbody><tr><td>Current</td><td>121676</td></tr><tr><td>Fully Paid</td><td>4908</td></tr><tr><td>Late (31-120 days)</td><td>849</td></tr><tr><td>In Grace Period</td><td>513</td></tr><tr><td>Late (16-30 days)</td><td>344</td></tr><tr><td>Charged Off</td><td>122</td></tr><tr><td>null</td><td>4</td></tr></tbody></table></div>

# %%
df_sel = df_sel.na.drop("all", subset=["loan_status"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sel.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df_sel.columns]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------+-----+-------+--------+----------+-----------+----------------+---------+----------+----------+---+-----------+----------+---------+------------------+---------+------------+--------------+
# term|home_ownership|grade|purpose|int_rate|addr_state|loan_status|application_type|loan_amnt|emp_length|annual_inc|dti|delinq_2yrs|revol_util|total_acc|num_tl_90g_dpd_24m|dti_joint|term_cleaned|emplen_cleaned|
# +----+--------------+-----+-------+--------+----------+-----------+----------------+---------+----------+----------+---+-----------+----------+---------+------------------+---------+------------+--------------+
# ...

# %%
df_sel.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[164]: 128412</div>

# %%
#
df_sel.describe("dti", "revol_util").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------------+----------+
# summary|              dti|revol_util|
# +-------+-----------------+----------+
#   count|           128175|    128256|
#    mean| 19.9331775307197|      null|
#  stddev|20.14354224347552|      null|
#     min|              0.0|        0%|
#     max|            999.0|    99.90%|
# +-------+-----------------+----------+
#
# </div>

# %%
# %sql
select ceil(REGEXP_REPLACE(revol_util, "\%", "")), count(*) from loanstatus_sel group by ceil(REGEXP_REPLACE(revol_util, "\%", ""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from loanstatus_sel where revol_util is null limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_sel = df_sel.withColumn("revolutil_cleaned", regexp_extract(col("revol_util"), "\\d+", 0))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sel.describe('revol_util', 'revolutil_cleaned').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+------------------+
# summary|revol_util| revolutil_cleaned|
# +-------+----------+------------------+
#   count|    128256|            128256|
#    mean|      null| 43.76206961077844|
#  stddev|      null|24.801849528207075|
#     min|        0%|                 0|
#     max|    99.90%|                99|
# +-------+----------+------------------+
#
# </div>

# %%
def fill_avg(df, colname):
  return df.select(colname).agg(avg(colname))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rev_avg = fill_avg(df_sel, "revolutil_cleaned")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import lit

rev_avg = fill_avg(df_sel, 'revolutil_cleaned').first()[0]
df_sel = df_sel.withColumn('rev_avg', lit(rev_avg))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import coalesce
df_sel = df_sel.withColumn('revolutil_cleaned', coalesce(col('revolutil_cleaned'), col('rev_avg')))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sel.describe('revol_util', 'revolutil_cleaned').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+------------------+
# summary|revol_util| revolutil_cleaned|
# +-------+----------+------------------+
#   count|    128256|            128412|
#    mean|      null| 43.76206961077843|
#  stddev|      null|24.786779696453944|
#     min|        0%|                 0|
#     max|    99.90%|                99|
# +-------+----------+------------------+
#
# </div>

# %%
df_sel = df_sel.withColumn("revolutil_cleaned", df_sel["revolutil_cleaned"].cast("double"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sel.describe('revol_util', 'revolutil_cleaned').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+------------------+
# summary|revol_util| revolutil_cleaned|
# +-------+----------+------------------+
#   count|    128256|            128412|
#    mean|      null| 43.76206961077843|
#  stddev|      null|24.786779696453944|
#     min|        0%|               0.0|
#     max|    99.90%|             183.0|
# +-------+----------+------------------+
#
# </div>

# %%
#
df_sel.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df_sel.columns]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------+-----+-------+--------+----------+-----------+----------------+---------+----------+----------+---+-----------+----------+---------+------------------+---------+------------+--------------+-----------------+-------+
# term|home_ownership|grade|purpose|int_rate|addr_state|loan_status|application_type|loan_amnt|emp_length|annual_inc|dti|delinq_2yrs|revol_util|total_acc|num_tl_90g_dpd_24m|dti_joint|term_cleaned|emplen_cleaned|revolutil_cleaned|rev_avg|
# ...

# %%
# %sql
select * from loanstatus_sel where dti is null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select application_type, dti, dti_joint from loanstats where dti is null limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_sel = df_sel.withColumn("dti_cleaned", coalesce(col("dti"), col("dti_joint")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sel.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df_sel.columns]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------+-----+-------+--------+----------+-----------+----------------+---------+----------+----------+---+-----------+----------+---------+------------------+---------+------------+--------------+-----------------+-------+-----------+
# term|home_ownership|grade|purpose|int_rate|addr_state|loan_status|application_type|loan_amnt|emp_length|annual_inc|dti|delinq_2yrs|revol_util|total_acc|num_tl_90g_dpd_24m|dti_joint|term_cleaned|emplen_cleaned|revolutil_cleaned|rev_avg|dti_cleaned|
# ...

# %%
##
df_sel.groupby('loan_status').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+------+
#        loan_status| count|
# +------------------+------+
#         Fully Paid|  4908|
#    In Grace Period|   513|
#        Charged Off|   122|
# Late (31-120 days)|   849|
#            Current|121676|
#  Late (16-30 days)|   344|
# +------------------+------+
#
# </div>

# %%
df_sel.where(df_sel.loan_status.isin(["Late (31-120 days)", "Charged Off", "In Grace Period", "Late (16-30 days)"])).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------------+-----+------------------+--------+----------+------------------+----------------+---------+----------+----------+-----+-----------+----------+---------+------------------+---------+------------+--------------+-----------------+-----------------+-----------+
#       term|home_ownership|grade|           purpose|int_rate|addr_state|       loan_status|application_type|loan_amnt|emp_length|annual_inc|  dti|delinq_2yrs|revol_util|total_acc|num_tl_90g_dpd_24m|dti_joint|term_cleaned|emplen_cleaned|revolutil_cleaned|          rev_avg|dti_cleaned|
# ...

# %%
##
df_sel = df_sel.withColumn("bad_loan", when(df_sel.loan_status.isin(["late (31-120 days)", "Charged Off", 
                                                                     "In Grace Period", "Late (16-30 days)"]), 'Yes').otherwise('No'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sel.groupBy('bad_loan').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+------+
# bad_loan| count|
# +--------+------+
#       No|127433|
#      Yes|   979|
# +--------+------+
#
# </div>

# %%
df_sel.filter(df_sel.bad_loan == "Yes").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------------+-----+------------------+--------+----------+---------------+----------------+---------+----------+----------+-----+-----------+----------+---------+------------------+---------+------------+--------------+-----------------+-----------------+-----------+--------+
#       term|home_ownership|grade|           purpose|int_rate|addr_state|    loan_status|application_type|loan_amnt|emp_length|annual_inc|  dti|delinq_2yrs|revol_util|total_acc|num_tl_90g_dpd_24m|dti_joint|term_cleaned|emplen_cleaned|revolutil_cleaned|          rev_avg|dti_cleaned|bad_loan|
# ...

# %%
df_sel.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- term: string (nullable = true)
# -- home_ownership: string (nullable = true)
# -- grade: string (nullable = true)
# -- purpose: string (nullable = true)
# -- int_rate: string (nullable = true)
# -- addr_state: string (nullable = true)
# -- loan_status: string (nullable = true)
# -- application_type: string (nullable = true)
# -- loan_amnt: integer (nullable = true)
# -- emp_length: string (nullable = true)
# -- annual_inc: double (nullable = true)
# -- dti: double (nullable = true)
# -- delinq_2yrs: integer (nullable = true)
# -- revol_util: string (nullable = true)
# -- total_acc: integer (nullable = true)
# ...

# %%
df_sel_final = df_sel.drop('revol_util', 'dti', 'dti_joint')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_sel_final.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- term: string (nullable = true)
# -- home_ownership: string (nullable = true)
# -- grade: string (nullable = true)
# -- purpose: string (nullable = true)
# -- int_rate: string (nullable = true)
# -- addr_state: string (nullable = true)
# -- loan_status: string (nullable = true)
# -- application_type: string (nullable = true)
# -- loan_amnt: integer (nullable = true)
# -- emp_length: string (nullable = true)
# -- annual_inc: double (nullable = true)
# -- delinq_2yrs: integer (nullable = true)
# -- total_acc: integer (nullable = true)
# -- num_tl_90g_dpd_24m: integer (nullable = true)
# ...

# %%
df_sel.stat.crosstab('bad_loan', 'grade').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+-----+-----+-----+-----+----+---+---+
# bad_loan_grade|    A|    B|    C|    D|   E|  F|  G|
# +--------------+-----+-----+-----+-----+----+---+---+
#             No|37895|35636|30732|16850|5854|371| 95|
#            Yes|  116|  225|  286|  222| 108| 16|  6|
# +--------------+-----+-----+-----+-----+----+---+---+
#
# </div>

# %%
df_sel.describe('dti_cleaned').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+
# summary|       dti_cleaned|
# +-------+------------------+
#   count|            128412|
#    mean|19.930878500451655|
#  stddev| 20.12807970280371|
#     min|               0.0|
#     max|             999.0|
# +-------+------------------+
#
# </div>

# %%
df_sel.describe('dti_cleaned').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+
# summary|       dti_cleaned|
# +-------+------------------+
#   count|            128412|
#    mean|19.930878500451655|
#  stddev| 20.12807970280371|
#     min|               0.0|
#     max|             999.0|
# +-------+------------------+
#
# </div>

# %%
df_sel.filter(df_sel.dti_cleaned > 100).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+--------------+-----+------------------+--------+----------+-----------+----------------+---------+----------+----------+------+-----------+----------+---------+------------------+---------+------------+--------------+-----------------+-----------------+-----------+--------+
#       term|home_ownership|grade|           purpose|int_rate|addr_state|loan_status|application_type|loan_amnt|emp_length|annual_inc|   dti|delinq_2yrs|revol_util|total_acc|num_tl_90g_dpd_24m|dti_joint|term_cleaned|emplen_cleaned|revolutil_cleaned|          rev_avg|dti_cleaned|bad_loan|
# ...

# %%
##
permanent_table_name = "lc_loan_data"
df_sel.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
REFRESH TABLE lc_loan_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from lc_loan_data limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
lc_df = spark.table('lc_loan_data')
display(lc_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(lc_df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select addr_state, sum(loan_amnt) from lc_loan_data group by addr_state
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import isnan, when, count, col, log
display(lc_df.groupBy("addr_state").agg((count(col("annual_inc"))).alias("count")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select addr_state, count(loan_amnt) from lc_loan_data where bad_loan='Yes' group by addr_state
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(lc_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select grade, sum(loan_amnt) as tot_loan_amnt from lc_loan_data group by grade
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>grade</th><th>tot_loan_amnt</th></tr></thead><tbody><tr><td>F</td><td>6326275</td></tr><tr><td>E</td><td>83832000</td></tr><tr><td>B</td><td>591596125</td></tr><tr><td>D</td><td>267034700</td></tr><tr><td>C</td><td>495916925</td></tr><tr><td>A</td><td>604816200</td></tr><tr><td>G</td><td>1387050</td></tr></tbody></table></div>

# %%
# %sql
select grade, bad_loan, sum(loan_amnt) as tot_loan_amnt from lc_loan_data group by grade, bad_loan
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
##
lc_df = lc_df.withColumn("exposure", when(lc_df.bad_loan=="No", col("revol_bal")).otherwise(-10*col("revol_bal")))
display(lc_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# ...

# %%
display(lc_df.groupBy("bad_loan", "grade").agg({"exposure": "sum"}))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# ...

# %%
##
from pyspark.sql.functions import isnan, when, count, col
lc_df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in lc_df.columns]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------+-----+-------+--------+----------+-----------+----------------+---------+----------+----------+---+-----------+----------+---------+------------------+---------+------------+--------------+-----------------+-------+-----------+--------+
# term|home_ownership|grade|purpose|int_rate|addr_state|loan_status|application_type|loan_amnt|emp_length|annual_inc|dti|delinq_2yrs|revol_util|total_acc|num_tl_90g_dpd_24m|dti_joint|term_cleaned|emplen_cleaned|revolutil_cleaned|rev_avg|dti_cleaned|bad_loan|
# ...

# %%
display(lc_df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in lc_df.columns]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select loan_amnt from lc_loan_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select loan_amnt, bad_loan from lc_loan_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select loan_amnt from lc_loan_data where bad_loan='Yes'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
##
from pyspark.sql.types import FloatType

def trim(string):
  return string.strip('%')

spark.udf.register("trimperct", trim)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[207]: &lt;function __main__.trim(string)&gt;</div>

# %%
# %sql
select int_rate, cast(trimperct(int_rate) as float) as int_rate_float from lc_loan_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select bad_loan, cast(trimperct(int_rate) as float) as int_rate_float from lc_loan_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select bad_loan, installment from lc_loan_data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
# %sql
select home_ownership, bad_loan, loan_amnt from lc_loan_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select grade, purpose, count(*) as count from lc_loan_data group by grade, purpose
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#
display(lc_df.groupBy('grade', 'loan_status').agg({'loan_status':'count'}))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select bad_loan, count(*) from lc_loan_data group by bad_loan
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>bad_loan</th><th>count(1)</th></tr></thead><tbody><tr><td>No</td><td>127433</td></tr><tr><td>Yes</td><td>979</td></tr></tbody></table></div>

# %%
# %sql
select installment, loan_amnt, bad_loan from lc_loan_data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
## Correlation
lc_df.stat.corr('installment', 'loan_amnt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# ...

# %%
##
pd_df = lc_df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.clf()
sns.distplot(pd_df.loc[pd_df['dti'].notnull() & (pd_df['dti']<50), 'dti'])
plt.xlabel('dti')
plt.ylabel('count')
display()

# %% [markdown]
# spark.conf.set("spark.sql.execution.arrow.enabled", "true")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.clf()
sns.countplot(pd_df.loc[pd_df['total_acc'] < 120, 'total_acc'], order=sorted(pd_df['total_acc'].unique()), saturation=1)
_, _ = plt.xticks(np.arrange(0, 120, 10), np.arrange(0, 120, 10))
plt.xlabel('total_acc')
plt.ylabel('count')
display()
