# %% [markdown]
# ## Description: This program scrapes and summarizes news articles

# %%
## Installing packages

# !pip install nltk
# !pip install newspaper3k

# %%
# Import the libraries
import nltk
from newspaper import Article

# %%
# Get the article
url = 'https://www.statnews.com/2020/03/17/a-fiasco-in-the-making-as-the-coronavirus-pandemic-takes-hold-we-are-making-decisions-without-reliable-data/'
article = Article(url)

# %%
# Do some NLP
article.download() # download the article
article.parse() # parse the article
nltk.download('punkt') #
article.nlp() # do NLP
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Get the authors
article.authors
# Out:
# ['John P.A. Ioannidis',
#  'Jaewon Ryu',
#  'Karen M. Murphy',
#  'Caroline Schulman',
#  'Morgan Medlock',
#  'Rajeev Venkayya',
#  'Ben Cardin']

# %%
# Get the publish date
article.publish_date
# Out:
# datetime.datetime(2020, 3, 17, 0, 0)

# %%
# Get the top image 
article.top_image
# Out:
# 'https://www.statnews.com/wp-content/uploads/2020/03/AP_20076697302948-1024x576.jpg'

# %%
# Get the article text
# print(article.text)

# %%
# Get a summary of the article 
print(article.summary)
# Out:
# If the pandemic dissipates — either on its own or because of these measures — short-term extreme social distancing and lockdowns may be bearable.
# The data collected so far on how many people are infected and how the epidemic is evolving are utterly unreliable.
# The case fatality rate there was 1.0%, but this was a largely elderly population, in which the death rate from Covid-19 is much higher.
# A population-wide case fatality rate of 0.05% is lower than seasonal influenza.
# Could the Covid-19 case fatality rate be that low?
